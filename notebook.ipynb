# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse import csr_matrix
from knn_recommender import Recommender

# %%
song_info = pd.read_csv('dataset/triplets.txt',sep='\t',header=None)
song_info.columns = ['user_id', 'song_id', 'listen_count']

# %%
song_info.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0

# %%
song_actual =  pd.read_csv('dataset/song_data.csv')
song_actual.drop_duplicates(['song_id'], inplace=True)

# %%
song_actual.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
df_songs = pd.merge(song_info, song_actual, on="song_id", how="left")

# %%
df_songs.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0
#
#              title                        release    artist_name    year
# 0         The Cove             Thicker Than Water   Jack Johnson     0.0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976.0
# 2         Stronger                     Graduation     Kanye West  2007.0
# 3   Constellations              In Between Dreams   Jack Johnson  2005.0
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999.0

# %%
print(f"There are {df_songs.shape[0]} observations in the dataset")
# Out:
# There are 20797 observations in the dataset

# %%
df_songs.isnull().sum()
# Out:
# user_id         0
# song_id         1
# listen_count    1
# title           1
# release         1
# artist_name     1
# year            1
# dtype: int64

# %%
df_songs = df_songs.dropna(subset=['title', 'release'])

# %%
df_songs.isnull().sum()
# Out:
# user_id         0
# song_id         0
# listen_count    0
# title           0
# release         0
# artist_name     0
# year            0
# dtype: int64

# %%
df_songs.dtypes
# Out:
# user_id          object
# song_id          object
# listen_count    float64
# title            object
# release          object
# artist_name      object
# year            float64
# dtype: object

# %%
unique_songs = df_songs['title'].unique().shape[0]
print(f"There are {unique_songs} unique songs in the dataset")
# Out:
# There are 7117 unique songs in the dataset

# %%
unique_artists = df_songs['artist_name'].unique().shape[0]
print(f"There are {unique_artists} unique artists in the dataset")
# Out:
# There are 2676 unique artists in the dataset

# %%
unique_users = df_songs['user_id'].unique().shape[0]
print(f"There are {unique_users} unique users in the dataset")
# Out:
# There are 794 unique users in the dataset

# %%
ten_top_songs = df_songs.groupby('title')['listen_count'].count().reset_index().sort_values(['listen_count', 'title'], ascending = [0,1])
ten_top_songs['percentage']  = round(ten_top_songs['listen_count'].div(ten_top_songs['listen_count'].sum())*100, 2)

# %%
ten_top_songs = ten_top_songs[:10]
ten_top_songs
# Out:
#                                                   title  listen_count  \
# 5093                                      Sehr kosmisch            83
# 1474                     Dog Days Are Over (Radio Edit)            72
# 5085                                            Secrets            67
# 6488                                               Undo            67
# 7062                                     You're The One            67
# 4836                                            Revelry            66
# 2567  Horn Concerto No. 4 in E flat K495: II. Romanc...            54
# 1931                                          Fireflies            52
# 6088                                      The Scientist            51
# 2489                                   Hey_ Soul Sister            48
#
#       percentage
# 5093        0.40
# 1474        0.35
# 5085        0.32
# 6488        0.32
# 7062        0.32
# 4836        0.32
# 2567        0.26
# 1931        0.25
# 6088        0.25
# 2489        0.23

# %%
ten_top_artists  = df_songs.groupby(['artist_name'])['listen_count'].count().reset_index().sort_values(['listen_count','artist_name'], ascending = [0,1])

# %%
ten_top_artists = ten_top_artists[:10]
ten_top_artists
# Out:
#                  artist_name  listen_count
# 503                 Coldplay           329
# 2265          The Black Keys           226
# 879   Florence + The Machine           205
# 1319           Kings Of Leon           195
# 1894               Radiohead           187
# 2338             The Killers           181
# 575                Daft Punk           172
# 767                   Eminem           171
# 1236           Justin Bieber           155
# 1089            Jack Johnson           137

# %%
listen_counts = pd.DataFrame(df_songs.groupby('listen_count').size(), columns=['count'])
print(f"The maximum time the same user listened to the same songs was: {listen_counts.reset_index(drop=False)['listen_count'].iloc[-1]}")
# Out:
# The maximum time the same user listened to the same songs was: 247.0

# %%
print(f"On average, a user listen to the same song {df_songs['listen_count'].mean()} times")
# Out:
# On average, a user listen to the same song 2.9222927486055013 times

# %%
song_user = df_songs.groupby('user_id')['song_id'].count()

# %%
print(f"A user listens to an average of {np.mean(song_user)} songs, with minimum {np.min(song_user)} and maximum {np.max(song_user)} songs")
# Out:
# A user listens to an average of 26.191435768261965 songs, with minimum 1 and maximum 401 songs

# %%
values_matrix = unique_users * unique_songs
zero_values_matrix = values_matrix - df_songs.shape[0]
print(f"The matrix of users x songs has {zero_values_matrix} values that are zero")
# Out:
# The matrix of users x songs has 5630102 values that are zero

# %%
song_ten_id = song_user[song_user > 26].index.to_list()
df_song_id_more_ten = df_songs[df_songs['user_id'].isin(song_ten_id)].reset_index(drop=True)

# %%
df_songs_features = df_song_id_more_ten.pivot(index='song_id', columns='user_id', values='listen_count').fillna(0)
mat_songs_features = csr_matrix(df_songs_features.values)

# %%
df_songs_features.head()
# Out:
# user_id             0039bd8483d578997718cdc0bf6c7c88b679f488  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             01655ae6bc52e29c9cd100a7dde4e9eeae5e4031  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             019d0d1c7a01f8736ba59a124160e5fc70666db7  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             063ef0cd02c950d0fe5799257907d85c0d341470  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             07caa920795cd4f20bfeeb0e192a5ddd9566ecdd  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             08d31ac4452516e702815fef13b2059aa8210034  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             0a00498b9d607844a8826184ae7278097d1c008a  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             0b03286244d1cb0662fefddade241f56a1bae573  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             0b9a6a7975b818259222ae7434a1095834d25b92  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             0dd93f61fe69f292ac336715ef607214efb3dbaa  ...  \
# song_id                                                       ...
# SOAAAGQ12A8C1420C8                                       0.0  ...
# SOAAEJI12AB0188AB5                                       0.0  ...
# SOAAFAC12A67ADF7EB                                       0.0  ...
# SOAAFYH12A8C13717A                                       0.0  ...
# SOAAKPM12A58A77210                                       0.0  ...
#
# user_id             f608c215606e6421a429ea28ad08243241d5347d  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             f694565a4451ed33e6741ede8cd3a7eaad66bb84  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             f8ae59c070d0b3fadc84c4d9f18475a61d7d37eb  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             f904f6ed9ac7c35f4771c69a9ef38e797e4e4baf  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             f927dddfe26b0c74ada3eaadca41bfb462c37ee4  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             fc604c906ec7bb98c494ef7659b0d3dc75503812  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             fd13b9d49c54e00ff413fe3c095ba581c7fc611e  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             fe76c9d535c5834e4a9b91c13e29be6460cb79c4  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             fed37c4c49c9f217b3371c2f2c0e7541656e55cf  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# user_id             ff18ea9a13583f7f7aaa83719e0b22ce5618e9cf
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
# SOAAFYH12A8C13717A                                       0.0
# SOAAKPM12A58A77210                                       0.0
#
# [5 rows x 229 columns]

# %%
df_unique_songs = df_songs.drop_duplicates(subset=['song_id']).reset_index(drop=True)[['song_id', 'title']]
decode_id_song = {
    song: i for i, song in 
    enumerate(list(df_unique_songs.set_index('song_id').loc[df_songs_features.index].title))
}

# %%
model = Recommender(metric='cosine', algorithm='brute', k=20, data=mat_songs_features, decode_id_song=decode_id_song)

# %%
df_songs[df_songs['artist_name'] == 'Eminem']
# Out:
#                                         user_id             song_id  \
# 80     4bd88bfb25263a75bbdd467e74018f4ae570e5df  SOKOXWU12AF72AD1BC
# 83     4bd88bfb25263a75bbdd467e74018f4ae570e5df  SOVEUVC12A6310EAF1
# 85     4bd88bfb25263a75bbdd467e74018f4ae570e5df  SOWGXOP12A6701E93A
# 153    b64cdd1a0bd907e5e00b39e345194768e330d652  SOKOXWU12AF72AD1BC
# 157    b64cdd1a0bd907e5e00b39e345194768e330d652  SOLXDDC12A6701FBFD
# ...                                         ...                 ...
# 20742  dac821fa75a40a9c1dd845864b120cda076f3813  SOTULEI12A58A7CB72
# 20745  dac821fa75a40a9c1dd845864b120cda076f3813  SOVIMJC12A6D4F92EC
# 20747  dac821fa75a40a9c1dd845864b120cda076f3813  SOVXUCJ12A6701FBC2
# 20748  dac821fa75a40a9c1dd845864b120cda076f3813  SOWBFFR12AF72A2AA1
# 20750  dac821fa75a40a9c1dd845864b120cda076f3813  SOWGXOP12A6701E93A
#
#        listen_count                    title                    release  \
# 80              4.0      The Real Slim Shady               Curtain Call
# 83              5.0             Just Lose It               Curtain Call
# 85              8.0               Without Me                 Without Me
# 153             1.0      The Real Slim Shady               Curtain Call
# 157             1.0                 I'm Back    The Marshall Mathers LP
# ...             ...                      ...                        ...
# 20742           1.0             Buffalo Bill            Relapse: Refill
# 20745          15.0             No Apologies  Eminem Presents The Re-Up
# 20747           4.0  Still Don't Give A Fuck          The Slim Shady LP
# 20748           1.0              Rock Bottom          The Slim Shady LP
# 20750           7.0               Without Me                 Without Me
#
#       artist_name    year
# 80         Eminem  2000.0
# 83         Eminem  2004.0
# 85         Eminem  2002.0
# 153        Eminem  2000.0
# 157        Eminem  2000.0
# ...           ...     ...
# 20742      Eminem  2009.0
# 20745      Eminem  2006.0
# 20747      Eminem  1999.0
# 20748      Eminem  1999.0
# 20750      Eminem  2002.0
#
# [171 rows x 7 columns]

# %%
song = 'The Real Slim Shady'

# %%
new_recommendations = model.make_recommendation(new_song=song, n_recommendations=10)
print(f"The recommendations for {song} are:")
print(f"{new_recommendations}")
# Out:
# Starting the recommendation process for The Real Slim Shady ...
# ... Done
# The recommendations for The Real Slim Shady are:
# ['Not Big', 'Rap Game', 'The Islander', 'R.A.K.I.M.', 'Universe & U', "Ain't No Sunshine", 'Pass Out (Instrumental)', 'Hey Baby', 'Black Horse And The Cherry Tree (Radio Version)', 'Te Amo']
